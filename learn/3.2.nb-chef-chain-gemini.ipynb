# %%
from dotenv import load_dotenv
load_dotenv()
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain.prompts import ChatPromptTemplate

chat = ChatGoogleGenerativeAI(model="gemini-1.5-flash",
                              temperature = 0.8, streaming=True)
chef_template = ChatPromptTemplate.from_messages([
    ("system", "You are world-class international chef. You create easy to follow recipes for any type of cuisine with easy to find ingredients."),
    ("human", "I want to cook {cuisine} food.")
])


chef_chain = chef_template | chat

# %%
veg_chef_prompt = ChatPromptTemplate.from_messages([
    ("system", "You are a vegetarian chef specialized on making traditional recipies vegetarian. You find alternative ingredients and explain their preparation."
    "You don't radically modify the recipe. if there is no alternative for a food just say you don't know how to replace it."),
    ("human", "{recipe}")
])

veg_chain = veg_chef_prompt | chat

final_chain = {"recipe": chef_chain} | veg_chain
final_chain.invoke({"cuisine": "korean"})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[84], line 10
#       7 veg_chain = veg_chef_prompt | chat
#       9 final_chain = {"recipe": chef_chain} | veg_chain
# ---> 10 final_chain.invoke({"cuisine": "korean"})
#
# File /mnt/c/0.iGoodWorks/wsl/fullstack-gpt/env/lib/python3.11/site-packages/langchain/schema/runnable/base.py:1213, in RunnableSequence.invoke(self, input, config)
#    1211 try:
#    1212     for i, step in enumerate(self.steps):
# -> 1213         input = step.invoke(
#    1214             input,
#    1215             # mark each step as a child run
#    1216             patch_config(
#    1217                 config, callbacks=run_manager.get_child(f"seq:step:{i+1}")
#    1218             ),
#    1219         )
#    1220 # finish the root run
#    1221 except BaseException as e:
#
# File /mnt/c/0.iGoodWorks/wsl/fullstack-gpt/env/lib/python3.11/site-packages/langchain/schema/runnable/base.py:1724, in RunnableParallel.invoke(self, input, config)
#    1711     with get_executor_for_config(config) as executor:
#    1712         futures = [
#    1713             executor.submit(
#    1714                 step.invoke,
#    (...)
#    1722             for key, step in steps.items()
#    1723         ]
# -> 1724         output = {key: future.result() for key, future in zip(steps, futures)}
#    1725 # finish the root run
#    1726 except BaseException as e:
#
# File /mnt/c/0.iGoodWorks/wsl/fullstack-gpt/env/lib/python3.11/site-packages/langchain/schema/runnable/base.py:1724, in <dictcomp>(.0)
#    1711     with get_executor_for_config(config) as executor:
#    1712         futures = [
#    1713             executor.submit(
#    1714                 step.invoke,
#    (...)
#    1722             for key, step in steps.items()
#    1723         ]
# -> 1724         output = {key: future.result() for key, future in zip(steps, futures)}
#    1725 # finish the root run
#    1726 except BaseException as e:
#
# File /usr/lib/python3.11/concurrent/futures/_base.py:456, in Future.result(self, timeout)
#     454     raise CancelledError()
#     455 elif self._state == FINISHED:
# --> 456     return self.__get_result()
#     457 else:
#     458     raise TimeoutError()
#
# File /usr/lib/python3.11/concurrent/futures/_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File /usr/lib/python3.11/concurrent/futures/thread.py:58, in _WorkItem.run(self)
#      55     return
#      57 try:
# ---> 58     result = self.fn(*self.args, **self.kwargs)
#      59 except BaseException as exc:
#      60     self.future.set_exception(exc)
#
# File /mnt/c/0.iGoodWorks/wsl/fullstack-gpt/env/lib/python3.11/site-packages/langchain/schema/runnable/base.py:1213, in RunnableSequence.invoke(self, input, config)
#    1211 try:
#    1212     for i, step in enumerate(self.steps):
# -> 1213         input = step.invoke(
#    1214             input,
#    1215             # mark each step as a child run
#    1216             patch_config(
#    1217                 config, callbacks=run_manager.get_child(f"seq:step:{i+1}")
#    1218             ),
#    1219         )
#    1220 # finish the root run
#    1221 except BaseException as e:
#
# File /mnt/c/0.iGoodWorks/wsl/fullstack-gpt/env/lib/python3.11/site-packages/langchain/schema/runnable/base.py:2294, in RunnableLambda.invoke(self, input, config, **kwargs)
#    2292 """Invoke this runnable synchronously."""
#    2293 if hasattr(self, "func"):
# -> 2294     return self._call_with_config(
#    2295         self._invoke,
#    2296         input,
#    2297         self._config(config, self.func),
#    2298     )
#    2299 else:
#    2300     raise TypeError(
#    2301         "Cannot invoke a coroutine function synchronously."
#    2302         "Use `ainvoke` instead."
#    2303     )
#
# File /mnt/c/0.iGoodWorks/wsl/fullstack-gpt/env/lib/python3.11/site-packages/langchain/schema/runnable/base.py:715, in Runnable._call_with_config(self, func, input, config, run_type, **kwargs)
#     708 run_manager = callback_manager.on_chain_start(
#     709     dumpd(self),
#     710     input,
#     711     run_type=run_type,
#     712     name=config.get("run_name"),
#     713 )
#     714 try:
# --> 715     output = call_func_with_variable_args(
#     716         func, input, config, run_manager, **kwargs
#     717     )
#     718 except BaseException as e:
#     719     run_manager.on_chain_error(e)
#
# File /mnt/c/0.iGoodWorks/wsl/fullstack-gpt/env/lib/python3.11/site-packages/langchain/schema/runnable/config.py:308, in call_func_with_variable_args(func, input, config, run_manager, **kwargs)
#     306 if run_manager is not None and accepts_run_manager(func):
#     307     kwargs["run_manager"] = run_manager
# --> 308 return func(input, **kwargs)
#
# File /mnt/c/0.iGoodWorks/wsl/fullstack-gpt/env/lib/python3.11/site-packages/langchain/schema/runnable/base.py:2227, in RunnableLambda._invoke(self, input, run_manager, config)
#    2221 def _invoke(
#    2222     self,
#    2223     input: Input,
#    2224     run_manager: CallbackManagerForChainRun,
#    2225     config: RunnableConfig,
#    2226 ) -> Output:
# -> 2227     output = call_func_with_variable_args(self.func, input, config, run_manager)
#    2228     # If the output is a runnable, invoke it
#    2229     if isinstance(output, Runnable):
#
# File /mnt/c/0.iGoodWorks/wsl/fullstack-gpt/env/lib/python3.11/site-packages/langchain/schema/runnable/config.py:308, in call_func_with_variable_args(func, input, config, run_manager, **kwargs)
#     306 if run_manager is not None and accepts_run_manager(func):
#     307     kwargs["run_manager"] = run_manager
# --> 308 return func(input, **kwargs)
#
# File /mnt/c/0.iGoodWorks/wsl/fullstack-gpt/env/lib/python3.11/site-packages/langchain_core/_api/deprecation.py:181, in deprecated.<locals>.deprecate.<locals>.warning_emitting_wrapper(*args, **kwargs)
#     179     warned = True
#     180     emit_warning()
# --> 181 return wrapped(*args, **kwargs)
#
# File /mnt/c/0.iGoodWorks/wsl/fullstack-gpt/env/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py:1074, in BaseChatModel.__call__(self, messages, stop, callbacks, **kwargs)
#    1066 @deprecated("0.1.7", alternative="invoke", removal="1.0")
#    1067 def __call__(
#    1068     self,
#    (...)
#    1072     **kwargs: Any,
#    1073 ) -> BaseMessage:
# -> 1074     generation = self.generate(
#    1075         [messages], stop=stop, callbacks=callbacks, **kwargs
#    1076     ).generations[0][0]
#    1077     if isinstance(generation, ChatGeneration):
#    1078         return generation.message
#
# File /mnt/c/0.iGoodWorks/wsl/fullstack-gpt/env/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py:683, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     680 for i, m in enumerate(messages):
#     681     try:
#     682         results.append(
# --> 683             self._generate_with_cache(
#     684                 m,
#     685                 stop=stop,
#     686                 run_manager=run_managers[i] if run_managers else None,
#     687                 **kwargs,
#     688             )
#     689         )
#     690     except BaseException as e:
#     691         if run_managers:
#
# File /mnt/c/0.iGoodWorks/wsl/fullstack-gpt/env/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py:908, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#     906 else:
#     907     if inspect.signature(self._generate).parameters.get("run_manager"):
# --> 908         result = self._generate(
#     909             messages, stop=stop, run_manager=run_manager, **kwargs
#     910         )
#     911     else:
#     912         result = self._generate(messages, stop=stop, **kwargs)
#
# File /mnt/c/0.iGoodWorks/wsl/fullstack-gpt/env/lib/python3.11/site-packages/langchain_google_genai/chat_models.py:953, in ChatGoogleGenerativeAI._generate(self, messages, stop, run_manager, tools, functions, safety_settings, tool_config, generation_config, cached_content, tool_choice, **kwargs)
#     938 def _generate(
#     939     self,
#     940     messages: List[BaseMessage],
#    (...)
#     951     **kwargs: Any,
#     952 ) -> ChatResult:
# --> 953     request = self._prepare_request(
#     954         messages,
#     955         stop=stop,
#     956         tools=tools,
#     957         functions=functions,
#     958         safety_settings=safety_settings,
#     959         tool_config=tool_config,
#     960         generation_config=generation_config,
#     961         cached_content=cached_content or self.cached_content,
#     962         tool_choice=tool_choice,
#     963     )
#     964     response: GenerateContentResponse = _chat_with_retry(
#     965         request=request,
#     966         **kwargs,
#     967         generation_method=self.client.generate_content,
#     968         metadata=self.default_metadata,
#     969     )
#     970     return _response_to_result(response)
#
# File /mnt/c/0.iGoodWorks/wsl/fullstack-gpt/env/lib/python3.11/site-packages/langchain_google_genai/chat_models.py:1193, in ChatGoogleGenerativeAI._prepare_request(self, messages, stop, tools, functions, safety_settings, tool_config, tool_choice, generation_config, cached_content)
#    1190         filtered_messages.append(message)
#    1191 messages = filtered_messages
# -> 1193 system_instruction, history = _parse_chat_history(
#    1194     messages,
#    1195     convert_system_message_to_human=self.convert_system_message_to_human,
#    1196 )
#    1197 if tool_choice:
#    1198     if not formatted_tools:
#
# File /mnt/c/0.iGoodWorks/wsl/fullstack-gpt/env/lib/python3.11/site-packages/langchain_google_genai/chat_models.py:422, in _parse_chat_history(input_messages, convert_system_message_to_human)
#     420         parts = [_convert_tool_message_to_part(message)]
#     421     else:
# --> 422         raise ValueError(
#     423             f"Unexpected message with type {type(message)} at the position {i}."
#     424         )
#     426     messages.append(Content(role=role, parts=parts))
#     427 return system_instruction, messages
#
# ValueError: Unexpected message with type <class 'tuple'> at the position 0.
