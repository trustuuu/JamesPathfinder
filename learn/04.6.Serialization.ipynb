# %%
from langchain.chat_models import ChatOpenAI
from langchain.llms import OpenAI
from langchain.callbacks import get_openai_callback
from langchain.llms.loading import load_llm

chat = ChatOpenAI(
    temperature=0.1,
    max_tokens=450,
    model="gpt-3.5-turbo-16k"
)

# llm = OpenAI(
#     temperature=0.1,
#     max_tokens=450,
#     model="gpt-3.5-turbo-16k"
# )

# llm.save("model.json")
# llm = load_llm("model.json")
# llm

with get_openai_callback() as usage:
    a = chat.predict("What is the recipe for soju")
    b = chat.predict("What is the recipe for bread")
    print(a, "\n")
    print(b, "\n")
    print(usage)
# Out:
# Here is a simple recipe for making soju at home:
#
# Ingredients:
# - 1 cup of rice
# - 1 cup of nuruk (Korean fermentation starter)
# - 10 cups of water
# - 1 tablespoon of yeast
# - 1 tablespoon of sugar (optional)
#
# Instructions:
# 1. Rinse the rice thoroughly until the water runs clear.
# 2. Soak the rice in water for about 1 hour, then drain.
# 3. Cook the rice in a rice cooker or on the stovetop until it becomes soft and sticky.
# 4. Let the cooked rice cool down to room temperature.
# 5. In a large pot, combine the cooled rice, nuruk, and water. Mix well.
# 6. Cover the pot with a clean cloth or plastic wrap and let it sit at room temperature for 7-10 days. Stir the mixture once a day.
# 7. After the fermentation period, strain the mixture through a cheesecloth or fine mesh strainer to remove any solids.
# 8. Dissolve the yeast and sugar (if using) in a small amount of warm water. Add this mixture to the strained liquid and stir well.
# 9. Transfer the liquid to a clean container with an airtight lid.
# 10. Let the soju ferment for an additional 2-3 days at room temperature.
# 11. Once the fermentation is complete, store the soju in the refrigerator to chill before serving.
# 12. Serve the homemade soju chilled in small shot glasses.
#
# Note: The fermentation time and alcohol content may vary depending on the temperature and other factors. It is important to follow proper sanitation practices during the fermentation process to avoid contamination.
#
# Here is a basic recipe for making bread:
#
# Ingredients:
# - 4 cups all-purpose flour
# - 2 teaspoons active dry yeast
# - 2 teaspoons salt
# - 2 tablespoons sugar
# - 2 tablespoons vegetable oil
# - 1 ½ cups warm water (around 110°F/43°C)
#
# Instructions:
# 1. In a large mixing bowl, combine the warm water and sugar. Stir until the sugar is dissolved.
# 2. Sprinkle the yeast over the water and let it sit for about 5 minutes until it becomes foamy.
# 3. Add the flour, salt, and vegetable oil to the bowl. Mix everything together until a dough forms.
# 4. Transfer the dough onto a floured surface and knead it for about 10 minutes until it becomes smooth and elastic. You can also use a stand mixer with a dough hook attachment for this step.
# 5. Place the dough in a greased bowl, cover it with a clean kitchen towel, and let it rise in a warm place for about 1-2 hours or until it doubles in size.
# 6. Once the dough has risen, punch it down to release any air bubbles. Shape it into a loaf by rolling it tightly and tucking the ends underneath.
# 7. Place the shaped dough into a greased loaf pan and cover it with the kitchen towel again. Let it rise for another 30-45 minutes.
# 8. Preheat your oven to 375°F (190°C).
# 9. Bake the bread in the preheated oven for about 30-35 minutes or until it turns golden brown and sounds hollow when tapped on the bottom.
# 10. Remove the bread from the oven and let it cool in the pan for a few minutes. Then transfer it to a wire rack to cool completely before slicing.
#
# Note: This is a basic bread recipe, and you can customize it by adding ingredients like herbs, cheese, or seeds to the dough for different flavors.
#
# Tokens Used: 758
# 	Prompt Tokens: 27
# 	Completion Tokens: 731
# Successful Requests: 2
# Total Cost (USD): $0.003005
